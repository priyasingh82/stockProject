# %% [raw]
# # Module 2- Plotting in Financial Markets

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data= pd.read_csv('week2.csv')
data.head()
# Out:
#    Unnamed: 0      Symbol Series        Date  Prev Close  Open Price  \
# 0           0  HEROMOTOCO     EQ  2017-05-15     3541.50      3541.0
# 1           1  HEROMOTOCO     EQ  2017-05-16     3515.45      3529.5
# 2           2  HEROMOTOCO     EQ  2017-05-17     3619.40      3615.0
# 3           3  HEROMOTOCO     EQ  2017-05-18     3645.95      3600.0
# 4           4  HEROMOTOCO     EQ  2017-05-19     3592.05      3597.0
#
#    High Price  Low Price  Last Price  Close Price  ...  Total Traded Quantity  \
# 0     3558.00    3504.60      3518.0      3515.45  ...                 215587
# 1     3631.80    3491.10      3623.0      3619.40  ...                 372398
# 2     3683.95    3595.05      3634.1      3645.95  ...                 338342
# 3     3639.00    3577.05      3586.0      3592.05  ...                 294013
# 4     3656.00    3533.75      3565.0      3571.65  ...                 270446
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0  7.587906e+08          17129           110769                   51.38
# 1  1.326266e+09          33654           147610                   39.64
# 2  1.235308e+09          27003           160855                   47.54
# 3  1.059170e+09          23822           143430                   48.78
# 4  9.717284e+08          26291           113208                   41.86
#
#    Check Month  Year  Day_Perc_Change                Trend
# 0     ok     5  2017         0.000000  Slight or No change
# 1     ok     5  2017         2.956947             Positive
# 2     ok     5  2017         0.733547      Slight positive
# 3     ok     5  2017        -1.478353                  NaN
# 4     ok     5  2017        -0.567921                  NaN
#
# [5 rows x 21 columns]

# %%
x=data['Date'].dtype
print(x)
data['Date']= pd.to_datetime(data['Date']) 
data.set_index('Date',drop=False)
# Out:
# object
#             Unnamed: 0      Symbol Series       Date  Prev Close  Open Price  \
# Date
# 2017-05-15           0  HEROMOTOCO     EQ 2017-05-15     3541.50     3541.00
# 2017-05-16           1  HEROMOTOCO     EQ 2017-05-16     3515.45     3529.50
# 2017-05-17           2  HEROMOTOCO     EQ 2017-05-17     3619.40     3615.00
# 2017-05-18           3  HEROMOTOCO     EQ 2017-05-18     3645.95     3600.00
# 2017-05-19           4  HEROMOTOCO     EQ 2017-05-19     3592.05     3597.00
# 2017-05-22           5  HEROMOTOCO     EQ 2017-05-22     3571.65     3596.75
# 2017-05-23           6  HEROMOTOCO     EQ 2017-05-23     3562.45     3593.90
# 2017-05-24           7  HEROMOTOCO     EQ 2017-05-24     3585.00     3585.00
# 2017-05-25           8  HEROMOTOCO     EQ 2017-05-25     3567.60     3567.60
# 2017-05-26           9  HEROMOTOCO     EQ 2017-05-26     3625.85     3626.10
# 2017-05-29          10  HEROMOTOCO     EQ 2017-05-29     3618.40     3621.90
# 2017-05-30          11  HEROMOTOCO     EQ 2017-05-30     3665.80     3660.00
# 2017-05-31          12  HEROMOTOCO     EQ 2017-05-31     3740.35     3735.00
# 2017-06-01          13  HEROMOTOCO     EQ 2017-06-01     3745.45     3742.00
# 2017-06-02          14  HEROMOTOCO     EQ 2017-06-02     3733.35     3758.80
# 2017-06-05          15  HEROMOTOCO     EQ 2017-06-05     3849.75     3850.00
# 2017-06-06          16  HEROMOTOCO     EQ 2017-06-06     3834.95     3844.00
# 2019-04-26        -0.315820  Slight or No change
# 2019-04-30        -3.538786                  NaN
# 2019-05-02         1.586480             Positive
# 2019-05-03         0.536897      Slight positive
# 2019-05-06        -1.329227                  NaN
# 2019-05-07        -0.156046  Slight or No change
# 2019-05-08        -1.094031                  NaN
# 2019-05-09         1.522183             Positive
# 2019-05-10        -1.199882                  NaN
# 2019-05-13         0.137598  Slight or No change
#
# [494 rows x 21 columns]

# %%
fig = plt.figure(figsize = (8,8))
plt.plot(data['Date'],data['Close Price'])
plt.ylabel('Close Price')
plt.xlabel('Date')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [raw]
# #2.3 Plot the daily volumes traded using stem plot .

# %%
fig = plt.figure(figsize = (12,6))
plt.plot(data['Date'],data['Total Traded Quantity'])
plt.ylabel('Total Traded Quantity')
plt.xlabel('Date')
plt.show()

# %% [markdown]
#  #2.4  Plot a pie chart for all the 'Trend'  You can use the groupby function with the trend column to group all days with the same trend into a single group before plotting the pie chart. From the grouped data, create a BAR plot of average & median values of the 'Total Traded Quantity' by Trend type.

# %%
new = data[['Trend','Date']].copy()
grouped_df = new.groupby('Trend')

    
def trending(n):
    if n=='Slight or No change':
        return 0
    elif n=='Slight positive':
        return 1
    elif n=='Slight negative':
        return -1
    elif n=="Positive":
        return 2
    elif n=="Negative":
        return -2
    elif n== 'Among top gainers':
        return 3
    elif n== 'Among top losers':
        return -3
    elif n=="Bull run":
        return 4
    elif n == 'Bear drop':
        return -4
data["Trending"]= data["Trend"].apply(trending) 
data
d= data["Trending"].value_counts(dropna=False)
print(d)
# Out:
# NaN    179
# 0.0    170
# 2.0     80
# 1.0     51
# 3.0     12
# 4.0      2
# Name: Trending, dtype: int64

# %%
fig = plt.figure(figsize = (8,8))
values = [170, 92, 80, 75, 51, 12,12,2]
percent=[]
for i in values:
    perc_days= (i/494)*100 
    perc_days=round(perc_days,2)
    percent.append(perc_days)
print(percent)    
labels = ['Slight or No change','Slight positive','Slight negative','Positive','Negative','Among top gainers','Among top losers','Bull run','Bear drop']

plt.pie(values, labels= percent,counterclock=False, shadow=True)
plt.title('Trends')
plt.legend(labels,loc=2)
plt.show()
# Out:
# [34.41, 18.62, 16.19, 15.18, 10.32, 2.43, 2.43, 0.4]

# %%
fig=plt.figure(figsize=(15,5))
fresh = data[['Trend','Total Traded Quantity']].copy()
a=fresh.groupby(['Trend'])['Total Traded Quantity'].mean()
a.plot.bar()

# %%
data['Day_Perc_Change'].plot.hist()

# %% [raw]
# 2.10 Trade Calls - Using Bollinger Bands
# Plot the bollinger bands for this stock - the duration of 14 days and 2 standard deviations away from the average
# The bollinger bands comprise the following data points-
# The 14 day rolling mean of the closing price (we call it the average)
# Upper band which is the rolling mean + 2 standard deviations away from the average.
# Lower band which is the rolling mean - 2 standard deviations away from the average.
# Average Daily stock price.
# Bollinger bands are extremely reliable , with a 95% accuracy at 2 standard deviations , and especially useful in sideways moving market.
# Observe the bands yourself , and analyse the accuracy of all the trade signals provided by the bollinger bands.
# Save to a new csv file.

# %%
import pandas as pd
data2=pd.read_csv('week2.csv')
data2.head()
# Out:
#    Unnamed: 0      Symbol Series        Date  Prev Close  Open Price  \
# 0           0  HEROMOTOCO     EQ  2017-05-15     3541.50      3541.0
# 1           1  HEROMOTOCO     EQ  2017-05-16     3515.45      3529.5
# 2           2  HEROMOTOCO     EQ  2017-05-17     3619.40      3615.0
# 3           3  HEROMOTOCO     EQ  2017-05-18     3645.95      3600.0
# 4           4  HEROMOTOCO     EQ  2017-05-19     3592.05      3597.0
#
#    High Price  Low Price  Last Price  Close Price  ...  Total Traded Quantity  \
# 0     3558.00    3504.60      3518.0      3515.45  ...                 215587
# 1     3631.80    3491.10      3623.0      3619.40  ...                 372398
# 2     3683.95    3595.05      3634.1      3645.95  ...                 338342
# 3     3639.00    3577.05      3586.0      3592.05  ...                 294013
# 4     3656.00    3533.75      3565.0      3571.65  ...                 270446
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0  7.587906e+08          17129           110769                   51.38
# 1  1.326266e+09          33654           147610                   39.64
# 2  1.235308e+09          27003           160855                   47.54
# 3  1.059170e+09          23822           143430                   48.78
# 4  9.717284e+08          26291           113208                   41.86
#
#    Check Month  Year  Day_Perc_Change                Trend
# 0     ok     5  2017         0.000000  Slight or No change
# 1     ok     5  2017         2.956947             Positive
# 2     ok     5  2017         0.733547      Slight positive
# 3     ok     5  2017        -1.478353                  NaN
# 4     ok     5  2017        -0.567921                  NaN
#
# [5 rows x 21 columns]

# %%
data2['moving_21']=data2['Close Price'].rolling(14).mean()
data2['std_dev']=data2['Close Price'].rolling(2).std()
data2['std_2']=data2['std_dev']*2
data3=data2.dropna()
data3['upper']=data3['moving_21']+data3['std_dev']
data3['lower']=data3['moving_21']-data3['std_dev']
data3.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Unnamed: 0      Symbol Series        Date  Prev Close  Open Price  \
# 13          13  HEROMOTOCO     EQ  2017-06-01     3745.45     3742.00
# 14          14  HEROMOTOCO     EQ  2017-06-02     3733.35     3758.80
# 15          15  HEROMOTOCO     EQ  2017-06-05     3849.75     3850.00
# 17          17  HEROMOTOCO     EQ  2017-06-07     3799.95     3803.85
# 19          19  HEROMOTOCO     EQ  2017-06-09     3784.45     3796.30
#
#     High Price  Low Price  Last Price  Close Price  ...  Check  Month  Year  \
# 13     3815.00    3708.80     3730.00      3733.35  ...     ok      6  2017
# 14     3857.50    3750.00     3849.95      3849.75  ...     ok      6  2017
# 15     3880.55    3821.25     3830.55      3834.95  ...     ok      6  2017
# 17     3856.05    3803.85     3841.00      3843.25  ...     ok      6  2017
# 19     3800.50    3755.60     3786.00      3780.10  ...     ok      6  2017
#
#     Day_Perc_Change                Trend    moving_21    std_dev       std_2  \
# 13        -0.323059  Slight or No change  3627.767857   8.555992   17.111984
# 14         3.117843    Among top gainers  3651.646429  82.307229  164.614459
# 15        -0.384441  Slight or No change  3667.042857  10.465180   20.930361
# 17         1.139489             Positive  3695.985714  30.617724   61.235447
# 19        -0.114944  Slight or No change  3726.732143   3.075914    6.151829
#
#           upper        lower
# 13  3636.323849  3619.211865
# 14  3733.953658  3569.339199
# 15  3677.508038  3656.577677
# 17  3726.603438  3665.367991
# 19  3729.808057  3723.656228
#
# [5 rows x 26 columns]

# %%
data3['upper'].plot.line(figsize=(15,5))
data3['lower'].plot.line(figsize=(15,5))

# %%
data3.to_csv('week3.csv')
